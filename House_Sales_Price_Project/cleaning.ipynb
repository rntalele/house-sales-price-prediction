# %%
import pandas as pd

# %%
df = pd.read_csv("Property_Price_Train.csv")

# %%
df.head()
# Out:
#    Id  Building_Class Zoning_Class  Lot_Extent  Lot_Size Road_Type Lane_Type  \
# 0   1              60          RLD        65.0      8450     Paved       NaN
# 1   2              20          RLD        80.0      9600     Paved       NaN
# 2   3              60          RLD        68.0     11250     Paved       NaN
# 3   4              70          RLD        60.0      9550     Paved       NaN
# 4   5              60          RLD        84.0     14260     Paved       NaN
#
#   Property_Shape Land_Outline Utility_Type  ... Pool_Area Pool_Quality  \
# 0            Reg          Lvl       AllPub  ...         0          NaN
# 1            Reg          Lvl       AllPub  ...         0          NaN
# 2            IR1          Lvl       AllPub  ...         0          NaN
# 3            IR1          Lvl       AllPub  ...         0          NaN
# 4            IR1          Lvl       AllPub  ...         0          NaN
#
#   Fence_Quality Miscellaneous_Feature Miscellaneous_Value Month_Sold  \
# ...

# %%
df.isnull()
# Out:
#          Id  Building_Class  Zoning_Class  Lot_Extent  Lot_Size  Road_Type  \
# 0     False           False         False       False     False      False
# 1     False           False         False       False     False      False
# 2     False           False         False       False     False      False
# 3     False           False         False       False     False      False
# 4     False           False         False       False     False      False
# ...     ...             ...           ...         ...       ...        ...
# 1454  False           False         False       False     False      False
# 1455  False           False         False       False     False      False
# 1456  False           False         False       False     False      False
# 1457  False           False         False       False     False      False
# 1458  False           False         False       False     False      False
#
# ...

# %%
dfback=df

# %%
df.drop(["Id","Year_Sold","Month_Sold"],inplace=True,axis=1)

# %%
df
# Out:
#       Building_Class Zoning_Class  Lot_Extent  Lot_Size Road_Type Lane_Type  \
# 0                 60          RLD        65.0      8450     Paved       NaN
# 1                 20          RLD        80.0      9600     Paved       NaN
# 2                 60          RLD        68.0     11250     Paved       NaN
# 3                 70          RLD        60.0      9550     Paved       NaN
# 4                 60          RLD        84.0     14260     Paved       NaN
# ...              ...          ...         ...       ...       ...       ...
# 1454              20          FVR        62.0      7500     Paved     Paved
# 1455              60          RLD        62.0      7917     Paved       NaN
# 1456              20          RLD        85.0     13175     Paved       NaN
# 1457              70          RLD        66.0      9042     Paved       NaN
# 1458              20          RLD        68.0      9717     Paved       NaN
#
# ...

# %%
df.isnull().sum()
# Out:
# Building_Class              0
# Zoning_Class                0
# Lot_Extent                259
# Lot_Size                    0
# Road_Type                   0
#                          ...
# Miscellaneous_Feature    1405
# Miscellaneous_Value         0
# Sale_Type                   0
# Sale_Condition              0
# Sale_Price                  0
# Length: 78, dtype: int64

# %%
len(df)
# Out:
# 1459

# %%
missing=df.isnull().sum()/len(df)
missing_features=missing.loc[missing>0.5].index
df.drop(missing_features,inplace=True,axis=1)

# %%
df
# Out:
#       Building_Class Zoning_Class  Lot_Extent  Lot_Size Road_Type  \
# 0                 60          RLD        65.0      8450     Paved
# 1                 20          RLD        80.0      9600     Paved
# 2                 60          RLD        68.0     11250     Paved
# 3                 70          RLD        60.0      9550     Paved
# 4                 60          RLD        84.0     14260     Paved
# ...              ...          ...         ...       ...       ...
# 1454              20          FVR        62.0      7500     Paved
# 1455              60          RLD        62.0      7917     Paved
# 1456              20          RLD        85.0     13175     Paved
# 1457              70          RLD        66.0      9042     Paved
# 1458              20          RLD        68.0      9717     Paved
#
#      Property_Shape Land_Outline Utility_Type Lot_Configuration  \
# 0               Reg          Lvl       AllPub                 I
# ...

# %%
df.corr()
# Out:
#                            Building_Class  Lot_Extent  Lot_Size  \
# Building_Class                   1.000000   -0.386327 -0.139852
# Lot_Extent                      -0.386327    1.000000  0.426103
# Lot_Size                        -0.139852    0.426103  1.000000
# Overall_Material                 0.032168    0.251850  0.105797
# House_Condition                 -0.059106   -0.059286 -0.005621
# Construction_Year                0.027734    0.123383  0.014220
# Remodel_Year                     0.040029    0.089063  0.013754
# Brick_Veneer_Area                0.022600    0.193581  0.104149
# BsmtFinSF1                      -0.069364    0.233563  0.214190
# BsmtFinSF2                      -0.064813    0.049682  0.111317
# BsmtUnfSF                       -0.141426    0.132874 -0.002658
# Total_Basement_Area             -0.238327    0.392038  0.260870
# First_Floor_Area                -0.251685    0.457158  0.299491
# Second_Floor_Area                0.307557    0.080335  0.050965
# ...

# %%
df.drop(["Building_Class","House_Condition","BsmtFinSF2","Garage_Area","W_Deck_Area","Open_Lobby_Area","Enclosed_Lobby_Area","Three_Season_Lobby_Area","Screen_Lobby_Area","Pool_Area","Miscellaneous_Value"],inplace=True,axis=1)

# %%
df
# Out:
#      Zoning_Class  Lot_Extent  Lot_Size Road_Type Property_Shape Land_Outline  \
# 0             RLD        65.0      8450     Paved            Reg          Lvl
# 1             RLD        80.0      9600     Paved            Reg          Lvl
# 2             RLD        68.0     11250     Paved            IR1          Lvl
# 3             RLD        60.0      9550     Paved            IR1          Lvl
# 4             RLD        84.0     14260     Paved            IR1          Lvl
# ...           ...         ...       ...       ...            ...          ...
# 1454          FVR        62.0      7500     Paved            Reg          Lvl
# 1455          RLD        62.0      7917     Paved            Reg          Lvl
# 1456          RLD        85.0     13175     Paved            Reg          Lvl
# 1457          RLD        66.0      9042     Paved            Reg          Lvl
# 1458          RLD        68.0      9717     Paved            Reg          Lvl
#
# ...

# %%
df.corr()
# Out:
#                            Lot_Extent  Lot_Size  Overall_Material  \
# Lot_Extent                   1.000000  0.426103          0.251850
# Lot_Size                     0.426103  1.000000          0.105797
# Overall_Material             0.251850  0.105797          1.000000
# Construction_Year            0.123383  0.014220          0.572342
# Remodel_Year                 0.089063  0.013754          0.550453
# Brick_Veneer_Area            0.193581  0.104149          0.411699
# BsmtFinSF1                   0.233563  0.214190          0.240239
# BsmtUnfSF                    0.132874 -0.002658          0.307794
# Total_Basement_Area          0.392038  0.260870          0.538210
# First_Floor_Area             0.457158  0.299491          0.476468
# Second_Floor_Area            0.080335  0.050965          0.295187
# LowQualFinSF                 0.038491  0.004774         -0.030502
# Grade_Living_Area            0.402925  0.263119          0.592916
# ...

# %%
df.drop(["Underground_Half_Bathroom","Bedroom_Above_Grade","Kitchen_Above_Grade"],inplace=True,axis=1)

# %%
df
# Out:
#      Zoning_Class  Lot_Extent  Lot_Size Road_Type Property_Shape Land_Outline  \
# 0             RLD        65.0      8450     Paved            Reg          Lvl
# 1             RLD        80.0      9600     Paved            Reg          Lvl
# 2             RLD        68.0     11250     Paved            IR1          Lvl
# 3             RLD        60.0      9550     Paved            IR1          Lvl
# 4             RLD        84.0     14260     Paved            IR1          Lvl
# ...           ...         ...       ...       ...            ...          ...
# 1454          FVR        62.0      7500     Paved            Reg          Lvl
# 1455          RLD        62.0      7917     Paved            Reg          Lvl
# 1456          RLD        85.0     13175     Paved            Reg          Lvl
# 1457          RLD        66.0      9042     Paved            Reg          Lvl
# 1458          RLD        68.0      9717     Paved            Reg          Lvl
#
# ...

# %%
df.corr()
# Out:
#                            Lot_Extent  Lot_Size  Overall_Material  \
# Lot_Extent                   1.000000  0.426103          0.251850
# Lot_Size                     0.426103  1.000000          0.105797
# Overall_Material             0.251850  0.105797          1.000000
# Construction_Year            0.123383  0.014220          0.572342
# Remodel_Year                 0.089063  0.013754          0.550453
# Brick_Veneer_Area            0.193581  0.104149          0.411699
# BsmtFinSF1                   0.233563  0.214190          0.240239
# BsmtUnfSF                    0.132874 -0.002658          0.307794
# Total_Basement_Area          0.392038  0.260870          0.538210
# First_Floor_Area             0.457158  0.299491          0.476468
# Second_Floor_Area            0.080335  0.050965          0.295187
# LowQualFinSF                 0.038491  0.004774         -0.030502
# Grade_Living_Area            0.402925  0.263119          0.592916
# ...

# %%
df.drop(["LowQualFinSF"],inplace=True,axis=1)

# %%
df.corr()
# Out:
#                            Lot_Extent  Lot_Size  Overall_Material  \
# Lot_Extent                   1.000000  0.426103          0.251850
# Lot_Size                     0.426103  1.000000          0.105797
# Overall_Material             0.251850  0.105797          1.000000
# Construction_Year            0.123383  0.014220          0.572342
# Remodel_Year                 0.089063  0.013754          0.550453
# Brick_Veneer_Area            0.193581  0.104149          0.411699
# BsmtFinSF1                   0.233563  0.214190          0.240239
# BsmtUnfSF                    0.132874 -0.002658          0.307794
# Total_Basement_Area          0.392038  0.260870          0.538210
# First_Floor_Area             0.457158  0.299491          0.476468
# Second_Floor_Area            0.080335  0.050965          0.295187
# Grade_Living_Area            0.402925  0.263119          0.592916
# Underground_Full_Bathroom    0.100811  0.158265          0.111773
# ...

# %%
df
# Out:
#      Zoning_Class  Lot_Extent  Lot_Size Road_Type Property_Shape Land_Outline  \
# 0             RLD        65.0      8450     Paved            Reg          Lvl
# 1             RLD        80.0      9600     Paved            Reg          Lvl
# 2             RLD        68.0     11250     Paved            IR1          Lvl
# 3             RLD        60.0      9550     Paved            IR1          Lvl
# 4             RLD        84.0     14260     Paved            IR1          Lvl
# ...           ...         ...       ...       ...            ...          ...
# 1454          FVR        62.0      7500     Paved            Reg          Lvl
# 1455          RLD        62.0      7917     Paved            Reg          Lvl
# 1456          RLD        85.0     13175     Paved            Reg          Lvl
# 1457          RLD        66.0      9042     Paved            Reg          Lvl
# 1458          RLD        68.0      9717     Paved            Reg          Lvl
#
# ...

# %%
df.corr()
# Out:
#                            Lot_Extent  Lot_Size  Overall_Material  \
# Lot_Extent                   1.000000  0.426103          0.251850
# Lot_Size                     0.426103  1.000000          0.105797
# Overall_Material             0.251850  0.105797          1.000000
# Construction_Year            0.123383  0.014220          0.572342
# Remodel_Year                 0.089063  0.013754          0.550453
# Brick_Veneer_Area            0.193581  0.104149          0.411699
# BsmtFinSF1                   0.233563  0.214190          0.240239
# BsmtUnfSF                    0.132874 -0.002658          0.307794
# Total_Basement_Area          0.392038  0.260870          0.538210
# First_Floor_Area             0.457158  0.299491          0.476468
# Second_Floor_Area            0.080335  0.050965          0.295187
# Grade_Living_Area            0.402925  0.263119          0.592916
# Underground_Full_Bathroom    0.100811  0.158265          0.111773
# ...

# %%
df.drop(["BsmtUnfSF","Underground_Full_Bathroom"],inplace=True,axis=1)

# %%
df
# Out:
#      Zoning_Class  Lot_Extent  Lot_Size Road_Type Property_Shape Land_Outline  \
# 0             RLD        65.0      8450     Paved            Reg          Lvl
# 1             RLD        80.0      9600     Paved            Reg          Lvl
# 2             RLD        68.0     11250     Paved            IR1          Lvl
# 3             RLD        60.0      9550     Paved            IR1          Lvl
# 4             RLD        84.0     14260     Paved            IR1          Lvl
# ...           ...         ...       ...       ...            ...          ...
# 1454          FVR        62.0      7500     Paved            Reg          Lvl
# 1455          RLD        62.0      7917     Paved            Reg          Lvl
# 1456          RLD        85.0     13175     Paved            Reg          Lvl
# 1457          RLD        66.0      9042     Paved            Reg          Lvl
# 1458          RLD        68.0      9717     Paved            Reg          Lvl
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 57 columns):
# Zoning_Class                 1459 non-null object
# Lot_Extent                   1200 non-null float64
# Lot_Size                     1459 non-null int64
# Road_Type                    1459 non-null object
# Property_Shape               1459 non-null object
# Land_Outline                 1459 non-null object
# Utility_Type                 1459 non-null object
# Lot_Configuration            1459 non-null object
# Property_Slope               1459 non-null object
# Neighborhood                 1459 non-null object
# Condition1                   1459 non-null object
# Condition2                   1459 non-null object
# House_Type                   1459 non-null object
# House_Design                 1459 non-null object
# Overall_Material             1459 non-null int64
# Construction_Year            1459 non-null int64
# Remodel_Year                 1459 non-null int64
# ...

# %%
for i in ["Lot_Extent"]:
    df[i].fillna(df[i].mean(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 57 columns):
# Zoning_Class                 1459 non-null object
# Lot_Extent                   1459 non-null float64
# Lot_Size                     1459 non-null int64
# Road_Type                    1459 non-null object
# Property_Shape               1459 non-null object
# Land_Outline                 1459 non-null object
# Utility_Type                 1459 non-null object
# Lot_Configuration            1459 non-null object
# Property_Slope               1459 non-null object
# Neighborhood                 1459 non-null object
# Condition1                   1459 non-null object
# Condition2                   1459 non-null object
# House_Type                   1459 non-null object
# House_Design                 1459 non-null object
# Overall_Material             1459 non-null int64
# Construction_Year            1459 non-null int64
# Remodel_Year                 1459 non-null int64
# ...

# %%
df.to_csv("progress.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 57 columns):
# Zoning_Class                 1459 non-null object
# Lot_Extent                   1459 non-null float64
# Lot_Size                     1459 non-null int64
# Road_Type                    1459 non-null object
# Property_Shape               1459 non-null object
# Land_Outline                 1459 non-null object
# Utility_Type                 1459 non-null object
# Lot_Configuration            1459 non-null object
# Property_Slope               1459 non-null object
# Neighborhood                 1459 non-null object
# Condition1                   1459 non-null object
# Condition2                   1459 non-null object
# House_Type                   1459 non-null object
# House_Design                 1459 non-null object
# Overall_Material             1459 non-null int64
# Construction_Year            1459 non-null int64
# Remodel_Year                 1459 non-null int64
# ...

# %%
for gar in ["Brick_Veneer_Type"]:
    df[gar].fillna("None",inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 57 columns):
# Zoning_Class                 1459 non-null object
# Lot_Extent                   1459 non-null float64
# Lot_Size                     1459 non-null int64
# Road_Type                    1459 non-null object
# Property_Shape               1459 non-null object
# Land_Outline                 1459 non-null object
# Utility_Type                 1459 non-null object
# Lot_Configuration            1459 non-null object
# Property_Slope               1459 non-null object
# Neighborhood                 1459 non-null object
# Condition1                   1459 non-null object
# Condition2                   1459 non-null object
# House_Type                   1459 non-null object
# House_Design                 1459 non-null object
# Overall_Material             1459 non-null int64
# Construction_Year            1459 non-null int64
# Remodel_Year                 1459 non-null int64
# ...

# %%
for ea in ["Brick_Veneer_Area"]:
    df[ea].fillna(0,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 57 columns):
# Zoning_Class                 1459 non-null object
# Lot_Extent                   1459 non-null float64
# Lot_Size                     1459 non-null int64
# Road_Type                    1459 non-null object
# Property_Shape               1459 non-null object
# Land_Outline                 1459 non-null object
# Utility_Type                 1459 non-null object
# Lot_Configuration            1459 non-null object
# Property_Slope               1459 non-null object
# Neighborhood                 1459 non-null object
# Condition1                   1459 non-null object
# Condition2                   1459 non-null object
# House_Type                   1459 non-null object
# House_Design                 1459 non-null object
# Overall_Material             1459 non-null int64
# Construction_Year            1459 non-null int64
# Remodel_Year                 1459 non-null int64
# ...

# %%
for a in ["Basement_Height"]:
    df[a].fillna("None",inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 57 columns):
# Zoning_Class                 1459 non-null object
# Lot_Extent                   1459 non-null float64
# Lot_Size                     1459 non-null int64
# Road_Type                    1459 non-null object
# Property_Shape               1459 non-null object
# Land_Outline                 1459 non-null object
# Utility_Type                 1459 non-null object
# Lot_Configuration            1459 non-null object
# Property_Slope               1459 non-null object
# Neighborhood                 1459 non-null object
# Condition1                   1459 non-null object
# Condition2                   1459 non-null object
# House_Type                   1459 non-null object
# House_Design                 1459 non-null object
# Overall_Material             1459 non-null int64
# Construction_Year            1459 non-null int64
# Remodel_Year                 1459 non-null int64
# ...

# %%
for b in ["Basement_Condition"]:
    df[b].fillna("None",inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 57 columns):
# Zoning_Class                 1459 non-null object
# Lot_Extent                   1459 non-null float64
# Lot_Size                     1459 non-null int64
# Road_Type                    1459 non-null object
# Property_Shape               1459 non-null object
# Land_Outline                 1459 non-null object
# Utility_Type                 1459 non-null object
# Lot_Configuration            1459 non-null object
# Property_Slope               1459 non-null object
# Neighborhood                 1459 non-null object
# Condition1                   1459 non-null object
# Condition2                   1459 non-null object
# House_Type                   1459 non-null object
# House_Design                 1459 non-null object
# Overall_Material             1459 non-null int64
# Construction_Year            1459 non-null int64
# Remodel_Year                 1459 non-null int64
# ...

# %%
for c in ["Exposure_Level"]:
    df[c].fillna("No",inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 57 columns):
# Zoning_Class                 1459 non-null object
# Lot_Extent                   1459 non-null float64
# Lot_Size                     1459 non-null int64
# Road_Type                    1459 non-null object
# Property_Shape               1459 non-null object
# Land_Outline                 1459 non-null object
# Utility_Type                 1459 non-null object
# Lot_Configuration            1459 non-null object
# Property_Slope               1459 non-null object
# Neighborhood                 1459 non-null object
# Condition1                   1459 non-null object
# Condition2                   1459 non-null object
# House_Type                   1459 non-null object
# House_Design                 1459 non-null object
# Overall_Material             1459 non-null int64
# Construction_Year            1459 non-null int64
# Remodel_Year                 1459 non-null int64
# ...

# %%
for d in ["BsmtFinType1"]:
    df[d].fillna("None",inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 57 columns):
# Zoning_Class                 1459 non-null object
# Lot_Extent                   1459 non-null float64
# Lot_Size                     1459 non-null int64
# Road_Type                    1459 non-null object
# Property_Shape               1459 non-null object
# Land_Outline                 1459 non-null object
# Utility_Type                 1459 non-null object
# Lot_Configuration            1459 non-null object
# Property_Slope               1459 non-null object
# Neighborhood                 1459 non-null object
# Condition1                   1459 non-null object
# Condition2                   1459 non-null object
# House_Type                   1459 non-null object
# House_Design                 1459 non-null object
# Overall_Material             1459 non-null int64
# Construction_Year            1459 non-null int64
# Remodel_Year                 1459 non-null int64
# ...

# %%
for e in ["BsmtFinType2"]:
    df[e].fillna("Unf",inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 57 columns):
# Zoning_Class                 1459 non-null object
# Lot_Extent                   1459 non-null float64
# Lot_Size                     1459 non-null int64
# Road_Type                    1459 non-null object
# Property_Shape               1459 non-null object
# Land_Outline                 1459 non-null object
# Utility_Type                 1459 non-null object
# Lot_Configuration            1459 non-null object
# Property_Slope               1459 non-null object
# Neighborhood                 1459 non-null object
# Condition1                   1459 non-null object
# Condition2                   1459 non-null object
# House_Type                   1459 non-null object
# House_Design                 1459 non-null object
# Overall_Material             1459 non-null int64
# Construction_Year            1459 non-null int64
# Remodel_Year                 1459 non-null int64
# ...

# %%
for f in ["Electrical_System"]:
    df[f].fillna("SBrkr",inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 57 columns):
# Zoning_Class                 1459 non-null object
# Lot_Extent                   1459 non-null float64
# Lot_Size                     1459 non-null int64
# Road_Type                    1459 non-null object
# Property_Shape               1459 non-null object
# Land_Outline                 1459 non-null object
# Utility_Type                 1459 non-null object
# Lot_Configuration            1459 non-null object
# Property_Slope               1459 non-null object
# Neighborhood                 1459 non-null object
# Condition1                   1459 non-null object
# Condition2                   1459 non-null object
# House_Type                   1459 non-null object
# House_Design                 1459 non-null object
# Overall_Material             1459 non-null int64
# Construction_Year            1459 non-null int64
# Remodel_Year                 1459 non-null int64
# ...

# %%
for g in ["Fireplace_Quality"]:
    df[g].fillna("None",inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 57 columns):
# Zoning_Class                 1459 non-null object
# Lot_Extent                   1459 non-null float64
# Lot_Size                     1459 non-null int64
# Road_Type                    1459 non-null object
# Property_Shape               1459 non-null object
# Land_Outline                 1459 non-null object
# Utility_Type                 1459 non-null object
# Lot_Configuration            1459 non-null object
# Property_Slope               1459 non-null object
# Neighborhood                 1459 non-null object
# Condition1                   1459 non-null object
# Condition2                   1459 non-null object
# House_Type                   1459 non-null object
# House_Design                 1459 non-null object
# Overall_Material             1459 non-null int64
# Construction_Year            1459 non-null int64
# Remodel_Year                 1459 non-null int64
# ...

# %%
df.corr()
# Out:
#                            Lot_Extent  Lot_Size  Overall_Material  \
# Lot_Extent                   1.000000  0.306801          0.234376
# Lot_Size                     0.306801  1.000000          0.105797
# Overall_Material             0.234376  0.105797          1.000000
# Construction_Year            0.117630  0.014220          0.572342
# Remodel_Year                 0.082924  0.013754          0.550453
# Brick_Veneer_Area            0.178810  0.103309          0.407075
# BsmtFinSF1                   0.215749  0.214190          0.240239
# Total_Basement_Area          0.363320  0.260870          0.538210
# First_Floor_Area             0.414243  0.299491          0.476468
# Second_Floor_Area            0.072622  0.050965          0.295187
# Grade_Living_Area            0.368504  0.263119          0.592916
# Full_Bathroom_Above_Grade    0.180651  0.126035          0.550358
# Half_Bathroom_Above_Grade    0.048091  0.014316          0.274328
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 57 columns):
# Zoning_Class                 1459 non-null object
# Lot_Extent                   1459 non-null float64
# Lot_Size                     1459 non-null int64
# Road_Type                    1459 non-null object
# Property_Shape               1459 non-null object
# Land_Outline                 1459 non-null object
# Utility_Type                 1459 non-null object
# Lot_Configuration            1459 non-null object
# Property_Slope               1459 non-null object
# Neighborhood                 1459 non-null object
# Condition1                   1459 non-null object
# Condition2                   1459 non-null object
# House_Type                   1459 non-null object
# House_Design                 1459 non-null object
# Overall_Material             1459 non-null int64
# Construction_Year            1459 non-null int64
# Remodel_Year                 1459 non-null int64
# ...

# %%
for h in ["Garage_Built_Year"]:
    df[h].fillna("No",inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 57 columns):
# Zoning_Class                 1459 non-null object
# Lot_Extent                   1459 non-null float64
# Lot_Size                     1459 non-null int64
# Road_Type                    1459 non-null object
# Property_Shape               1459 non-null object
# Land_Outline                 1459 non-null object
# Utility_Type                 1459 non-null object
# Lot_Configuration            1459 non-null object
# Property_Slope               1459 non-null object
# Neighborhood                 1459 non-null object
# Condition1                   1459 non-null object
# Condition2                   1459 non-null object
# House_Type                   1459 non-null object
# House_Design                 1459 non-null object
# Overall_Material             1459 non-null int64
# Construction_Year            1459 non-null int64
# Remodel_Year                 1459 non-null int64
# ...

# %%
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %%
dfback=df

# %%
df=dfback

# %%
df.corr()
# Out:
#                            Lot_Extent  Lot_Size  Overall_Material  \
# Lot_Extent                   1.000000  0.306801          0.234376
# Lot_Size                     0.306801  1.000000          0.105797
# Overall_Material             0.234376  0.105797          1.000000
# Construction_Year            0.117630  0.014220          0.572342
# Remodel_Year                 0.082924  0.013754          0.550453
# Brick_Veneer_Area            0.178810  0.103309          0.407075
# BsmtFinSF1                   0.215749  0.214190          0.240239
# Total_Basement_Area          0.363320  0.260870          0.538210
# First_Floor_Area             0.414243  0.299491          0.476468
# Second_Floor_Area            0.072622  0.050965          0.295187
# Grade_Living_Area            0.368504  0.263119          0.592916
# Full_Bathroom_Above_Grade    0.180651  0.126035          0.550358
# Half_Bathroom_Above_Grade    0.048091  0.014316          0.274328
# ...

# %%
df.to_csv("cleaned_data.csv")

# %%
X=df[['Overall_Material','Construction_Year','Remodel_Year','Total_Basement_Area','First_Floor_Area','Grade_Living_Area','Garage_Size','Rooms_Above_Grade']].values
y=df['Sale_Price'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = regressor.predict(X_test)

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df1 = df.head(25)

# %%
df1
# Out:
#     Actual      Predicted
# 0   223000  218687.427313
# 1    91300   94424.800064
# 2   140000  171867.912476
# 3   135960  130609.928915
# 4   156000  133600.249570
# 5   130000  134139.708790
# 6   141000  164352.735286
# 7   174000  218366.384063
# 8    75000   83625.087106
# 9   109008   81532.887016
# 10   98300  104281.417191
# 11  325000  282250.715208
# 12   91000  104748.539409
# 13  226700  218769.807541
# 14  301500  283007.548265
# 15  155000  165001.701547
# 16  173733  167213.881214
# 17  415298  334694.214835
# 18  246578  241165.740243
# 19  177000  166735.761530
# 20  287000  323008.593697
# 21  100000   52137.103457
# 22  149350  143256.091801
# 23  208900  217635.772928
# 24   82500  207160.102554

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
print("Mean squared error: %.2f"% mean_squared_error(y_test, y_pred))
# Out:
# Mean squared error: 1102378776.67

# %%
print("Regression score: %.2f" % r2_score(y_test,y_pred))
# Out:
# Regression score: 0.82
