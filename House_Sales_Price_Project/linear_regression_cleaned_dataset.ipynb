# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %%
df=pd.read_csv("progress.csv")

# %%
df2=df

# %%
df
# Out:
#       Unnamed: 0 Zoning_Class  Lot_Extent  Lot_Size Road_Type Property_Shape  \
# 0              0          RLD        65.0      8450     Paved            Reg
# 1              1          RLD        80.0      9600     Paved            Reg
# 2              2          RLD        68.0     11250     Paved            IR1
# 3              3          RLD        60.0      9550     Paved            IR1
# 4              4          RLD        84.0     14260     Paved            IR1
# ...          ...          ...         ...       ...       ...            ...
# 1454        1454          FVR        62.0      7500     Paved            Reg
# 1455        1455          RLD        62.0      7917     Paved            Reg
# 1456        1456          RLD        85.0     13175     Paved            Reg
# 1457        1457          RLD        66.0      9042     Paved            Reg
# 1458        1458          RLD        68.0      9717     Paved            Reg
#
# ...

# %%
df.corr()
# Out:
#                            Unnamed: 0  Lot_Extent  Lot_Size  Overall_Material  \
# Unnamed: 0                   1.000000   -0.009879 -0.033191         -0.027456
# Lot_Extent                  -0.009879    1.000000  0.306801          0.234376
# Lot_Size                    -0.033191    0.306801  1.000000          0.105797
# Overall_Material            -0.027456    0.234376  0.105797          1.000000
# Construction_Year           -0.012479    0.117630  0.014220          0.572342
# Remodel_Year                -0.020884    0.082924  0.013754          0.550453
# Brick_Veneer_Area           -0.049671    0.179812  0.104149          0.411699
# BsmtFinSF1                  -0.006037    0.215749  0.214190          0.240239
# Total_Basement_Area         -0.015969    0.363320  0.260870          0.538210
# First_Floor_Area             0.010220    0.414243  0.299491          0.476468
# Second_Floor_Area            0.006541    0.072622  0.050965          0.295187
# ...

# %%
X=df[['Overall_Material','Construction_Year','Remodel_Year','Lot_Extent','Remodel_Year','BsmtFinSF1','Total_Basement_Area','First_Floor_Area','Second_Floor_Area','Grade_Living_Area','Full_Bathroom_Above_Grade','Rooms_Above_Grade','Fireplaces','Garage_Size']].values
y=df['Sale_Price'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = regressor.predict(X_test)

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df1 = df.head(25)

# %%
df1
# Out:
#     Actual      Predicted
# 0   223000  221139.665733
# 1    91300   91855.407302
# 2   140000  163697.758907
# 3   135960  152287.002599
# 4   156000  137786.395559
# 5   130000  139739.030764
# 6   141000  167201.194793
# 7   174000  206312.342280
# 8    75000   79756.930683
# 9   109008   77761.579342
# 10   98300  103218.054987
# 11  325000  304340.580559
# 12   91000  103019.315650
# 13  226700  215089.740513
# 14  301500  286972.219723
# 15  155000  169222.610176
# 16  173733  163142.082955
# 17  415298  313663.898604
# 18  246578  249472.517070
# 19  177000  175490.308198
# 20  287000  321183.749735
# 21  100000   65046.379757
# 22  149350  131769.169265
# 23  208900  206977.915424
# 24   82500  211724.287597

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 21890.901551885312
# Mean Squared Error: 975764100.6497858
# Root Mean Squared Error: 31237.22299836824
